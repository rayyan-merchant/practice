# %% [markdown]
# ![image.png](attachment:image.png)

# %%
X = ' '
Q = 'Q'
N = 8

queens = set([(0, 6), (1, 4), (2, 1), (3, 3), (4, 5), (5, 7), (6, 2), (7, 0)])
board = [[Q if (r, c) in queens else X for c in range(N)] for r in range(N)]

board
# Out:
# [[' ', ' ', ' ', ' ', ' ', ' ', 'Q', ' '],
#  [' ', ' ', ' ', ' ', 'Q', ' ', ' ', ' '],
#  [' ', 'Q', ' ', ' ', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', 'Q', ' ', ' ', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', 'Q', ' ', ' '],
#  [' ', ' ', ' ', ' ', ' ', ' ', ' ', 'Q'],
#  [' ', ' ', 'Q', ' ', ' ', ' ', ' ', ' '],
#  ['Q', ' ', ' ', ' ', ' ', ' ', ' ', ' ']]
